# %%
import pandas as pd
import json
from pandas import json_normalize

# %%
with open("C:\citrix overføring\\110820.json", encoding="utf8") as json_file:
    data = json.load(json_file)

# %%
df = pd.json_normalize(data=data)
#'key' before :['list' , 'other keys', 'innerlist name', 'innerlist key']

# %%
df.to_csv('json_normalize140820.csv', encoding="utf8")

# %%
df.info()
# Out:
#  DOFFIN_ESENDERS.FORM_SECTION.CONTRACT_AWARD.FD_CONTRACT_AWARD.@CTYPE                                                                                                                                                                                           8439 non-null    object
#  8   DOFFIN_ESENDERS.FORM_SECTION.CONTRACT_AWARD.FD_CONTRACT_AWARD.CONTRACTING_AUTHORITY_INFORMATION_CONTRACT_AWARD.NAME_ADDRESSES_CONTACT_CONTRACT_AWARD.CA_CE_CONCESSIONAIRE_PROFILE.ORGANISATION.OFFICIALNAME                                                    8439 non-null    object
#  9   DOFFIN_ESENDERS.FORM_SECTION.CONTRACT_AWARD.FD_CONTRACT_AWARD.CONTRACTING_AUTHORITY_INFORMATION_CONTRACT_AWARD.NAME_ADDRESSES_CONTACT_CONTRACT_AWARD.CA_CE_CONCESSIONAIRE_PROFILE.ORGANISATION.NATIONALID                                                      7270 non-null    object
# ...

# %%
df.rename(columns=lambda x: x.replace('DOFFIN_ESENDERS', 'D'), inplace=True)

# %%
df.info()
# Out:
#                                                                                                                                           8439 non-null    object
#  4   D.FORM_SECTION.CONTRACT_AWARD.@CATEGORY                                                                                                                                                                                                          8439 non-null    object
#  5   D.FORM_SECTION.CONTRACT_AWARD.@FORM                                                                                                                                                                                                              8439 non-null    object
#  6   D.FORM_SECTION.CONTRACT_AWARD.@VERSION                                                                                                                                                                                                           8439 non-null    object
# ...

# %%
df.rename(columns=lambda x: x.replace('FORM_SECTION', 'FS'), inplace=True)

# %%
df.info()
# Out:
#                                                                                      107846 non-null  object
#  1   D.@VERSION                                                                                                                                                                                                                             101959 non-null  object
#  2   D.@xmlns.xsi                                                                                                                                                                                                                           105651 non-null  object
#  3   D.FS.CONTRACT_AWARD.@LG                                                                                                                                                                                                                8439 non-null    object
# ...

# %%
df.rename(columns=lambda x: x.replace('CONTRACT_AWARD', 'CA'), inplace=True)

# %%
df.rename(columns=lambda x: x.replace('DOFFIN_APPENDIX', 'DA'), inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107846 entries, 0 to 107845
# Data columns (total 77 columns):
#  #   Column                                                                                                                                                                                 Non-Null Count   Dtype
# ---  ------                                                                                                                                                                                 --------------   -----
#  0   _id.$oid                                                                                                                                                                               107846 non-null  object
#  1   D.@VERSION                                                                                                                                                                             101959 non-null  object
# ...

# %%
df.rename(columns=lambda x: x.replace('OBJECT_CONTRACT_INFORMATION_CA_NOTICE', 'oci'), inplace=True)

# %%
df.rename(columns=lambda x: x.replace('AWARD_OF_CONTRACT', 'aoc'), inplace=True)

# %%
df.rename(columns=lambda x: x.replace('CONTRACTING_AUTHORITY_INFORMATION_CA', 'CAI'), inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107846 entries, 0 to 107845
# Data columns (total 77 columns):
#  #   Column                                                                                                                                                                                 Non-Null Count   Dtype
# ---  ------                                                                                                                                                                                 --------------   -----
#  0   _id.$oid                                                                                                                                                                               107846 non-null  object
#  1   D.@VERSION                                                                                                                                                                             101959 non-null  object
# ...

# %%
df.rename(columns=lambda x: x.replace('NAME_ADDRESSES_CONTACT_CA', 'cace'), inplace=True)
df.rename(columns=lambda x: x.replace('TYPE_AND_ACTIVITIES_AND_PURCHASING_ON_BEHALF', 'taaapb'), inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107846 entries, 0 to 107845
# Data columns (total 77 columns):
#  #   Column                                                                                                                                                                                 Non-Null Count   Dtype
# ---  ------                                                                                                                                                                                 --------------   -----
#  0   _id.$oid                                                                                                                                                                               107846 non-null  object
#  1   D.@VERSION                                                                                                                                                                             101959 non-null  object
# ...

# %%
df.rename(columns=lambda x: x.replace('DESCRIPTION_AWARD_NOTICE_INFORMATION', 'dani'), inplace=True)
df.rename(columns=lambda x: x.replace('TOTAL_FINAL_VALUE', 'tfv'), inplace=True)
df.rename(columns=lambda x: x.replace('PROCEDURE_DEFINITION_CA_NOTICE', 'pdca'), inplace=True)
df.rename(columns=lambda x: x.replace('ECONOMIC_OPERATOR_NAME_ADDRESS', 'eona'), inplace=True)
df.rename(columns=lambda x: x.replace('CONTRACT_VALUE_INFORMATION', 'cvi'), inplace=True)
df.rename(columns=lambda x: x.replace('MORE_INFORMATION_TO_SUB_CONTRACTED', 'mifsc'), inplace=True)
df.rename(columns=lambda x: x.replace('COMPLEMENTARY_INFORMATION_CA', 'cia'), inplace=True)
df.rename(columns=lambda x: x.replace('DOFFIN_FORM_TYPE', 'dft'), inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107846 entries, 0 to 107845
# Data columns (total 77 columns):
#  #   Column                                                                                                                                                       Non-Null Count   Dtype
# ---  ------                                                                                                                                                       --------------   -----
#  0   _id.$oid                                                                                                                                                     107846 non-null  object
#  1   D.@VERSION                                                                                                                                                   101959 non-null  object
# ...

# %%
df.rename(columns=lambda x: x.replace('AWARD_CRITERIA_CA_NOTICE_INFORMATION', 'accni'), inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107846 entries, 0 to 107845
# Data columns (total 77 columns):
#  #   Column                                                                                                                         Non-Null Count   Dtype
# ---  ------                                                                                                                         --------------   -----
#  0   _id.$oid                                                                                                                       107846 non-null  object
#  1   D.@VERSION                                                                                                                     101959 non-null  object
#  2   D.@xmlns.xsi                                                                                                                   105651 non-null  object
# ...

# %%
#df.rename(columns={'DOFFIN_ESENDERS.FORM_SECTION.CONTRACT_AWARD.FD_CONTRACT_AWARD.@CTYPE': 'FD_CONTRACT_AWARD.@CTYPE', 'DOFFIN_ESENDERS.FORM_SECTION.CONTRACT_AWARD.FD_CONTRACT_AWARD.CONTRACTING_AUTHORITY_INFORMATION_CONTRACT_AWARD.NAME_ADDRESSES_CONTACT_CONTRACT_AWARD.CA_CE_CONCESSIONAIRE_PROFILE.ORGANISATION.OFFICIALNAME': 'CA_CE_CONCESSIONAIRE_PROFILE.ORGANISATION.OFFICIALNAME', 'DOFFIN_ESENDERS.FORM_SECTION.CONTRACT_AWARD.FD_CONTRACT_AWARD.CONTRACTING_AUTHORITY_INFORMATION_CONTRACT_AWARD.NAME_ADDRESSES_CONTACT_CONTRACT_AWARD.CA_CE_CONCESSIONAIRE_PROFILE.ORGANISATION.NATIONALID': 'CA_CE_CONCESSIONAIRE_PROFILE.ORGANISATION.NATIONALID', 'DOFFIN_ESENDERS.FORM_SECTION.CONTRACT_AWARD.FD_CONTRACT_AWARD.CONTRACTING_AUTHORITY_INFORMATION_CONTRACT_AWARD.NAME_ADDRESSES_CONTACT_CONTRACT_AWARD.CA_CE_CONCESSIONAIRE_PROFILE.ADDRESS': 'CA_CE_CONCESSIONAIRE_PROFILE.ADDRESS', 'DOFFIN_ESENDERS.FORM_SECTION.CONTRACT_AWARD.FD_CONTRACT_AWARD.CONTRACTING_AUTHORITY_INFORMATION_CONTRACT_AWARD.NAME_ADDRESSES_CONTACT_CONTRACT_AWARD.CA_CE_CONCESSIONAIRE_PROFILE.TOWN': 'CA_CE_CONCESSIONAIRE_PROFILE.TOWN', 'DOFFIN_ESENDERS.FORM_SECTION.CONTRACT_AWARD.FD_CONTRACT_AWARD.CONTRACTING_AUTHORITY_INFORMATION_CONTRACT_AWARD.NAME_ADDRESSES_CONTACT_CONTRACT_AWARD.CA_CE_CONCESSIONAIRE_PROFILE.POSTAL_CODE': 'CA_CE_CONCESSIONAIRE_PROFILE.POSTAL_CODE', 'DOFFIN_ESENDERS.FORM_SECTION.CONTRACT_AWARD.FD_CONTRACT_AWARD.CONTRACTING_AUTHORITY_INFORMATION_CONTRACT_AWARD.NAME_ADDRESSES_CONTACT_CONTRACT_AWARD.CA_CE_CONCESSIONAIRE_PROFILE.COUNTRY.@VALUE': 'CA_CE_CONCESSIONAIRE_PROFILE.COUNTRY.@VALUE', 'DOFFIN_ESENDERS.FORM_SECTION.CONTRACT_AWARD.FD_CONTRACT_AWARD.CONTRACTING_AUTHORITY_INFORMATION_CONTRACT_AWARD.NAME_ADDRESSES_CONTACT_CONTRACT_AWARD.CA_CE_CONCESSIONAIRE_PROFILE.CONTACT_POINT': 'CA_CE_CONCESSIONAIRE_PROFILE.CONTACT_POINT', 'DOFFIN_ESENDERS.FORM_SECTION.CONTRACT_AWARD.FD_CONTRACT_AWARD.CONTRACTING_AUTHORITY_INFORMATION_CONTRACT_AWARD.NAME_ADDRESSES_CONTACT_CONTRACT_AWARD.CA_CE_CONCESSIONAIRE_PROFILE.PHONE': 'CA_CE_CONCESSIONAIRE_PROFILE.PHONE', 'DOFFIN_ESENDERS.FORM_SECTION.CONTRACT_AWARD.FD_CONTRACT_AWARD.CONTRACTING_AUTHORITY_INFORMATION_CONTRACT_AWARD.NAME_ADDRESSES_CONTACT_CONTRACT_AWARD.CA_CE_CONCESSIONAIRE_PROFILE.E_MAILS.E_MAIL': 'CA_CE_CONCESSIONAIRE_PROFILE.E_MAILS.E_MAIL', 'DOFFIN_ESENDERS.FORM_SECTION.CONTRACT_AWARD.FD_CONTRACT_AWARD.CONTRACTING_AUTHORITY_INFORMATION_CONTRACT_AWARD.NAME_ADDRESSES_CONTACT_CONTRACT_AWARD.INTERNET_ADDRESSES_CONTRACT_AWARD.URL_BUYER': 'INTERNET_ADDRESSES_CONTRACT_AWARD.URL_BUYER', 'DOFFIN_ESENDERS.FORM_SECTION.CONTRACT_AWARD.FD_CONTRACT_AWARD.CONTRACTING_AUTHORITY_INFORMATION_CONTRACT_AWARD.NAME_ADDRESSES_CONTACT_CONTRACT_AWARD.INTERNET_ADDRESSES_CONTRACT_AWARD.URL_INFORMATION': 'INTERNET_ADDRESSES_CONTRACT_AWARD.URL_INFORMATION', 'DOFFIN_ESENDERS.FORM_SECTION.CONTRACT_AWARD.FD_CONTRACT_AWARD.CONTRACTING_AUTHORITY_INFORMATION_CONTRACT_AWARD.TYPE_AND_ACTIVITIES_AND_PURCHASING_ON_BEHALF.TYPE_AND_ACTIVITIES.TYPE_OF_CONTRACTING_AUTHORITY.@VALUE': 'TYPE_AND_ACTIVITIES_AND_PURCHASING_ON_BEHALF.TYPE_AND_ACTIVITIES.TYPE_OF_CONTRACTING_AUTHORITY.@VALUE', 'DOFFIN_ESENDERS.FORM_SECTION.CONTRACT_AWARD.FD_CONTRACT_AWARD.CONTRACTING_AUTHORITY_INFORMATION_CONTRACT_AWARD.TYPE_AND_ACTIVITIES_AND_PURCHASING_ON_BEHALF.TYPE_AND_ACTIVITIES.TYPE_OF_ACTIVITY.@VALUE': 'TYPE_AND_ACTIVITIES_AND_PURCHASING_ON_BEHALF.TYPE_AND_ACTIVITIES.TYPE_OF_ACTIVITY.@VALUE', 'DOFFIN_ESENDERS.FORM_SECTION.CONTRACT_AWARD.FD_CONTRACT_AWARD.CONTRACTING_AUTHORITY_INFORMATION_CONTRACT_AWARD.TYPE_AND_ACTIVITIES_AND_PURCHASING_ON_BEHALF.PURCHASING_ON_BEHALF.PURCHASING_ON_BEHALF_NO': 'PURCHASING_ON_BEHALF.PURCHASING_ON_BEHALF_NO', 'DOFFIN_ESENDERS.FORM_SECTION.CONTRACT_AWARD.FD_CONTRACT_AWARD.OBJECT_CONTRACT_INFORMATION_CONTRACT_AWARD_NOTICE.DESCRIPTION_AWARD_NOTICE_INFORMATION.TITLE_CONTRACT.P': 'TITLE_CONTRACT.P'}, inplace=True)

# %%
df['D.FS.CA.@CATEGORY'].unique()
# Out:
# array(['ORIGINAL', nan], dtype=object)

# %%
df['D.FS.CA.@CATEGORY'] = df['D.FS.CA.@CATEGORY'].astype('category')

# %%
df['D.FS.CA.@CATEGORY'].dtype
# Out:
# CategoricalDtype(categories=['ORIGINAL'], ordered=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107846 entries, 0 to 107845
# Data columns (total 77 columns):
#  #   Column                                                                                                                         Non-Null Count   Dtype
# ---  ------                                                                                                                         --------------   -----
#  0   _id.$oid                                                                                                                       107846 non-null  object
#  1   D.@VERSION                                                                                                                     101959 non-null  object
#  2   D.@xmlns.xsi                                                                                                                   105651 non-null  object
# ...

# %%
df['D.FS.CA.FD_CA.@CTYPE'].dtype
df['D.FS.CA.FD_CA.@CTYPE'].unique
df['D.FS.CA.FD_CA.@CTYPE'] = df['D.FS.CA.FD_CA.@CTYPE'].astype('category')

# %%
df['D.FS.CA.FD_CA.CAI.cace.CA_CE_CONCESSIONAIRE_PROFILE.ORGANISATION.OFFICIALNAME'].dtype
df['D.FS.CA.FD_CA.CAI.cace.CA_CE_CONCESSIONAIRE_PROFILE.ORGANISATION.OFFICIALNAME'].unique
# Out:
# <bound method Series.unique of 0         Oslo universitetssykehus HF
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#                      ...
# 107841                            NaN
# 107842                            NaN
# 107843                            NaN
# 107844                            NaN
# 107845                            NaN
# Name: D.FS.CA.FD_CA.CAI.cace.CA_CE_CONCESSIONAIRE_PROFILE.ORGANISATION.OFFICIALNAME, Length: 107846, dtype: object>

# %%
df['D.FS.CA.FD_CA.CAI.cace.CA_CE_CONCESSIONAIRE_PROFILE.ORGANISATION.OFFICIALNAME'] = df['D.FS.CA.FD_CA.CAI.cace.CA_CE_CONCESSIONAIRE_PROFILE.ORGANISATION.OFFICIALNAME'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107846 entries, 0 to 107845
# Data columns (total 77 columns):
#  #   Column                                                                                                                         Non-Null Count   Dtype
# ---  ------                                                                                                                         --------------   -----
#  0   _id.$oid                                                                                                                       107846 non-null  object
#  1   D.@VERSION                                                                                                                     101959 non-null  object
#  2   D.@xmlns.xsi                                                                                                                   105651 non-null  object
# ...

# %%
df['D.FS.CA.@FORM'].dtype
df['D.FS.CA.@FORM'].unique()
df['D.FS.CA.@FORM'] = df['D.FS.CA.@FORM'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107846 entries, 0 to 107845
# Data columns (total 77 columns):
#  #   Column                                                                                                                         Non-Null Count   Dtype
# ---  ------                                                                                                                         --------------   -----
#  0   _id.$oid                                                                                                                       107846 non-null  object
#  1   D.@VERSION                                                                                                                     101959 non-null  object
#  2   D.@xmlns.xsi                                                                                                                   105651 non-null  object
# ...

# %%
df['D.FS.CA.@LG'].unique()
# Out:
# array(['NB', nan], dtype=object)

# %%
df['D.FS.CA.@LG'] = df['D.FS.CA.@LG'].astype('category')

# %%
df['D.FS.CA.FD_CA.CAI.taaapb.TYPE_AND_ACTIVITIES.TYPE_OF_ACTIVITY.@VALUE'].unique()
# Out:
# array(['HEALTH', nan, 'DEFENCE', 'GENERAL_PUBLIC_SERVICES', 'EDUCATION',
#        'HOUSING_AND_COMMUNITY_AMENITIES', 'ENVIRONMENT',
#        'RECREATION_CULTURE_AND_RELIGION', 'PUBLIC_ORDER_AND_SAFETY',
#        'ECONOMIC_AND_FINANCIAL_AFFAIRS', 'SOCIAL_PROTECTION'],
#       dtype=object)

# %%
df['D.FS.CA.FD_CA.CAI.taaapb.TYPE_AND_ACTIVITIES.TYPE_OF_ACTIVITY.@VALUE'] = df['D.FS.CA.FD_CA.CAI.taaapb.TYPE_AND_ACTIVITIES.TYPE_OF_ACTIVITY.@VALUE'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107846 entries, 0 to 107845
# Data columns (total 77 columns):
#  #   Column                                                                                                                         Non-Null Count   Dtype
# ---  ------                                                                                                                         --------------   -----
#  0   _id.$oid                                                                                                                       107846 non-null  object
#  1   D.@VERSION                                                                                                                     101959 non-null  object
#  2   D.@xmlns.xsi                                                                                                                   105651 non-null  object
# ...

# %%
df['D.FS.CA.FD_CA.CAI.cace.CA_CE_CONCESSIONAIRE_PROFILE.ORGANISATION.OFFICIALNAME'].unique()
# Out:
# [Oslo universitetssykehus HF, NaN, Forsvarsbygg, Arendal kommune, Helsedirektoratet, ..., NORD-TRØNDELAG FYLKESKOMMUNE, Meldal kommune co/FINANSinnkjøp AS, Hattfjelldal kommune, Rygge kommune, Nationaltheatret AS]
# Length: 1283
# Categories (1282, object): [Oslo universitetssykehus HF, Forsvarsbygg, Arendal kommune, Helsedirektoratet, ..., Meldal kommune co/FINANSinnkjøp AS, Hattfjelldal kommune, Rygge kommune, Nationaltheatret AS]

# %%
df['D.FS.CA.FD_CA.CAI.cace.CA_CE_CONCESSIONAIRE_PROFILE.ORGANISATION.OFFICIALNAME'] = df['D.FS.CA.FD_CA.CAI.cace.CA_CE_CONCESSIONAIRE_PROFILE.ORGANISATION.OFFICIALNAME'].astype('category')

# %%
df['D.FS.CA.FD_CA.CAI.taaapb.PURCHASING_ON_BEHALF.PURCHASING_ON_BEHALF_NO'].dtype
# Out:
# dtype('float64')

# %%
df['D.FS.CA.FD_CA.CAI.taaapb.PURCHASING_ON_BEHALF.PURCHASING_ON_BEHALF_NO'] = df['D.FS.CA.FD_CA.CAI.taaapb.PURCHASING_ON_BEHALF.PURCHASING_ON_BEHALF_NO'].astype('category')

# %%
df['D.FS.CA.FD_CA.CAI.taaapb.PURCHASING_ON_BEHALF.PURCHASING_ON_BEHALF_NO'].unique()
# Out:
# [NaN]
# Categories (0, float64): []

# %%
df['D.FS.CA.FD_CA.oci.tfv.COSTS_RANGE_AND_CURRENCY_WITH_VAT_RATE.@CURRENCY'].unique()
# Out:
# array(['NOK', nan, 'EUR', 'USD', 'CHF', 'DKK', 'SEK'], dtype=object)

# %%
df['D.FS.CA.FD_CA.oci.tfv.COSTS_RANGE_AND_CURRENCY_WITH_VAT_RATE.@CURRENCY'] = df['D.FS.CA.FD_CA.oci.tfv.COSTS_RANGE_AND_CURRENCY_WITH_VAT_RATE.@CURRENCY'].astype('category')

# %%
df['D.FS.CA.FD_CA.oci.tfv.COSTS_RANGE_AND_CURRENCY_WITH_VAT_RATE.VALUE_COST'].unique()
# Out:
# array(['1000000', nan, '4800000', ..., '18654000', '1434929743',
#        '3566000'], dtype=object)

# %%
df['D.FS.CA.FD_CA.oci.tfv.COSTS_RANGE_AND_CURRENCY_WITH_VAT_RATE.VALUE_COST'].astype(float)
# Out:
# 0         1000000.0
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#             ...
# 107841          NaN
# 107842          NaN
# 107843          NaN
# 107844          NaN
# 107845          NaN
# Name: D.FS.CA.FD_CA.oci.tfv.COSTS_RANGE_AND_CURRENCY_WITH_VAT_RATE.VALUE_COST, Length: 107846, dtype: float64

# %%
df['D.FS.CA.FD_CA.oci.tfv.COSTS_RANGE_AND_CURRENCY_WITH_VAT_RATE.VALUE_COST'].unique()
# Out:
# array(['1000000', nan, '4800000', ..., '18654000', '1434929743',
#        '3566000'], dtype=object)

# %%
df['D.FS.CA.FD_CA.oci.tfv.COSTS_RANGE_AND_CURRENCY_WITH_VAT_RATE.VALUE_COST'].describe()
# Out:
# count        3507
# unique       1642
# top       2000000
# freq          121
# Name: D.FS.CA.FD_CA.oci.tfv.COSTS_RANGE_AND_CURRENCY_WITH_VAT_RATE.VALUE_COST, dtype: object

# %%
df['D.FS.CA.FD_CA.oci.tfv.COSTS_RANGE_AND_CURRENCY_WITH_VAT_RATE.INCLUDING_VAT.VAT_PRCT'].astype(float)
# Out:
# 0         25.0
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#           ...
# 107841     NaN
# 107842     NaN
# 107843     NaN
# 107844     NaN
# 107845     NaN
# Name: D.FS.CA.FD_CA.oci.tfv.COSTS_RANGE_AND_CURRENCY_WITH_VAT_RATE.INCLUDING_VAT.VAT_PRCT, Length: 107846, dtype: float64

# %%
df['D.FS.CA.FD_CA.pdca.TYPE_OF_PROCEDURE_DEF.PT_OPEN'].describe()
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: D.FS.CA.FD_CA.pdca.TYPE_OF_PROCEDURE_DEF.PT_OPEN, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107846 entries, 0 to 107845
# Data columns (total 77 columns):
#  #   Column                                                                                                                         Non-Null Count   Dtype
# ---  ------                                                                                                                         --------------   -----
#  0   _id.$oid                                                                                                                       107846 non-null  object
#  1   D.@VERSION                                                                                                                     101959 non-null  object
#  2   D.@xmlns.xsi                                                                                                                   105651 non-null  object
# ...

# %%
df['D.FS.CA.FD_CA.oci.tfv.COSTS_RANGE_AND_CURRENCY_WITH_VAT_RATE.VALUE_COST'].unique()
# Out:
# array(['1000000', nan, '4800000', ..., '18654000', '1434929743',
#        '3566000'], dtype=object)

# %%
df['D.FS.CA.FD_CA.oci.tfv.COSTS_RANGE_AND_CURRENCY_WITH_VAT_RATE.VALUE_COST'].astype(float)
# Out:
# 0         1000000.0
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#             ...
# 107841          NaN
# 107842          NaN
# 107843          NaN
# 107844          NaN
# 107845          NaN
# Name: D.FS.CA.FD_CA.oci.tfv.COSTS_RANGE_AND_CURRENCY_WITH_VAT_RATE.VALUE_COST, Length: 107846, dtype: float64

# %%
df['D.FS.CA.FD_CA.oci.tfv.COSTS_RANGE_AND_CURRENCY_WITH_VAT_RATE.VALUE_COST'].unique()
# Out:
# array(['1000000', nan, '4800000', ..., '18654000', '1434929743',
#        '3566000'], dtype=object)
